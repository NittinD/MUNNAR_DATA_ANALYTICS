# %% [markdown]
# <a href="https://colab.research.google.com/github/NittinD/MUNNAR_DATA_ANALYTICS/blob/main/munnar_data_analytics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import Libraries

# %%
import pandas as pd
import sys

# %% [markdown]
# ** Load Data**

# %%
df=pd.read_csv('/munnar.csv')

df
# Out:
#                          Hotel Name\t\t\t\t\t\t\t\t\t  Rating  \
# 0                                        Gokulam Park     4.1
# 1                                     Sterling Munnar     3.8
# 2                                    Issacs Residency     4.1
# 3                                   Tea Valley Resort     4.3
# 4                                         Grand Plaza     4.3
# ..                                                ...     ...
# 69                      The Fog Munnar (Resort & Spa)     4.5
# 70               Skylark Holidays | Rooms & Caretaker     4.1
# 71  Deshadan Mountain Resort- The highest resort i...     4.3
# 72                          Nature Zone Jungle Resort     4.1
# 73    Lumino Highrange Homestay | Room & Guided Treks     3.2
#
#    Rating Description  Reviews  Star Rating         Location  \
# 0           Very Good     1058          4.0   Chithirapuram
# 1           Very Good     1088          4.0     Chinnakanal
# ...

# %% [markdown]
# **Data Overview**- head,tail,columns,rename,shape,info,astype

# %%
#                        This shows that df is an instance of the                          pandas.DataFrame class.
# If df is of a different type, such as a list or dictionary, it will print the corresponding type for that object.


print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
#  used to access the column names of a DataFrame df

df.columns
# Out:
# Index(['Hotel Name\t\t\t\t\t\t\t\t\t', 'Rating', 'Rating Description',
#        'Reviews', 'Star Rating', 'Location', 'Nearest Landmark',
#        'Distance to Landmark', 'Price', 'Tax'],
#       dtype='object')

# %%
df.rename({'Hotel Name\t\t\t\t\t\t\t\t\t':'Hotel Name'}, axis=1,inplace=True)

# %%
[i for i in df.columns]
# Out:
# ['Hotel Name',
#  'Rating',
#  'Rating Description',
#  'Reviews',
#  'Star Rating',
#  'Location',
#  'Nearest Landmark',
#  'Distance to Landmark',
#  'Price',
#  'Tax']

# %%
df.shape
# Out:
# (74, 10)

# %%
## data glimpse

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74 entries, 0 to 73
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Hotel Name            74 non-null     object
#  1   Rating                74 non-null     float64
#  2   Rating Description    74 non-null     object
#  3   Reviews               74 non-null     int64
#  4   Star Rating           57 non-null     float64
#  5   Location              74 non-null     object
#  6   Nearest Landmark      74 non-null     object
#  7   Distance to Landmark  74 non-null     object
#  8   Price                 74 non-null     object
#  9   Tax                   72 non-null     object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 5.9+ KB

# %%
import sys

# Print the shape of the DataFrame
print("Shape of DataFrame:", df.shape)

# Print DataFrame information (columns, non-null counts, dtypes)
print("\nDataFrame Info:")
df.info()

# Print the memory size of the DataFrame object itself
print("\nMemory used by the DataFrame object:")
print(sys.getsizeof(df))

# Print the total memory usage of the DataFrame, including data inside the DataFrame
print("\nTotal memory usage (including data inside df):")
print(df.memory_usage(deep=True).sum())

# Print the DataFrame index (this will print it in a spaced line)
print("\nIndex of DataFrame:")
print(df.index)
# Out:
# Shape of DataFrame: (74, 10)
#
# DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74 entries, 0 to 73
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Hotel Name            74 non-null     object
#  1   Rating                74 non-null     float64
#  2   Rating Description    74 non-null     object
#  3   Reviews               74 non-null     int64
#  4   Star Rating           57 non-null     float64
#  5   Location              74 non-null     object
#  6   Nearest Landmark      74 non-null     object
#  7   Distance to Landmark  74 non-null     object
#  8   Price                 74 non-null     object
#  9   Tax                   72 non-null     object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 5.9+ KB
#
# Memory used by the DataFrame object:
# 36994
#
# Total memory usage (including data inside df):
# 36962
#
# Index of DataFrame:
# ...

# %%
df.loc[0]
df.reset_index(inplace=True, drop=True)
df
# Out:
#                                            Hotel Name  Rating  \
# 0                                        Gokulam Park     4.1
# 1                                     Sterling Munnar     3.8
# 2                                    Issacs Residency     4.1
# 3                                   Tea Valley Resort     4.3
# 4                                         Grand Plaza     4.3
# ..                                                ...     ...
# 69                      The Fog Munnar (Resort & Spa)     4.5
# 70               Skylark Holidays | Rooms & Caretaker     4.1
# 71  Deshadan Mountain Resort- The highest resort i...     4.3
# 72                          Nature Zone Jungle Resort     4.1
# 73    Lumino Highrange Homestay | Room & Guided Treks     3.2
#
#    Rating Description  Reviews  Star Rating         Location  \
# 0           Very Good     1058          4.0   Chithirapuram
# 1           Very Good     1088          4.0     Chinnakanal
# ...

# %%
df.nunique
# Out:
# <bound method DataFrame.nunique of                                            Hotel Name  Rating  \
# 0                                        Gokulam Park     4.1
# 1                                     Sterling Munnar     3.8
# 2                                    Issacs Residency     4.1
# 3                                   Tea Valley Resort     4.3
# 4                                         Grand Plaza     4.3
# ..                                                ...     ...
# 69                      The Fog Munnar (Resort & Spa)     4.5
# 70               Skylark Holidays | Rooms & Caretaker     4.1
# 71  Deshadan Mountain Resort- The highest resort i...     4.3
# 72                          Nature Zone Jungle Resort     4.1
# 73    Lumino Highrange Homestay | Room & Guided Treks     3.2
#
#    Rating Description  Reviews  Star Rating         Location  \
# 0           Very Good     1058          4.0   Chithirapuram
# 1           Very Good     1088          4.0     Chinnakanal
# ...

# %%
df.nunique()
# Out:
# Hotel Name              74
# Rating                  18
# Rating Description       4
# Reviews                 70
# Star Rating              4
# Location                22
# Nearest Landmark         2
# Distance to Landmark    57
# Price                   72
# Tax                     70
# dtype: int64

# %% [markdown]
# Descriptive Statistics ----Generate basic statistical details:

# %%
df.dtypes
# Out:
# Hotel Name               object
# Rating                  float64
# Rating Description       object
# Reviews                   int64
# Star Rating             float64
# Location                 object
# Nearest Landmark         object
# Distance to Landmark     object
# Price                    object
# Tax                      object
# dtype: object

# %%
df['Tax']=df['Tax'].apply(lambda x:str(x))
df['Tax']=df['Tax'].apply(lambda x : x.replace(",", ""))
df['Tax']=pd.to_numeric(df['Tax'],errors='coerce')
df['Tax']=df['Tax'].astype('float64')
df['Tax']
# Out:
# 0      574.0
# 1      969.0
# 2      684.0
# 3      756.0
# 4      654.0
#        ...
# 69    2178.0
# 70     684.0
# 71     808.0
# 72    2124.0
# 73     223.0
# Name: Tax, Length: 74, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74 entries, 0 to 73
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Hotel Name            74 non-null     object
#  1   Rating                74 non-null     float64
#  2   Rating Description    74 non-null     object
#  3   Reviews               74 non-null     int64
#  4   Star Rating           57 non-null     float64
#  5   Location              74 non-null     object
#  6   Nearest Landmark      74 non-null     object
#  7   Distance to Landmark  74 non-null     float64
#  8   Price                 74 non-null     float64
#  9   Tax                   72 non-null     float64
# dtypes: float64(5), int64(1), object(4)
# memory usage: 5.9+ KB

# %%
import seaborn as sns
sns.distplot(df['Tax'])
# Out:
# <ipython-input-35-14a8bbf3d6dd>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Tax'])
# <Axes: xlabel='Tax', ylabel='Density'>

# %%
col=df['Tax']
col=col.fillna(col.mean(),inplace=True)

# %%
sns.distplot(df['Star Rating'])
# Out:
# <ipython-input-37-6946f45f53fe>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Star Rating'])
# <Axes: xlabel='Star Rating', ylabel='Density'>

# %%
col=df['Star Rating']
col=col.fillna(col.mean(),inplace=True)

# %%
df.isna().sum()
# Out:
# Hotel Name              0
# Rating                  0
# Rating Description      0
# Reviews                 0
# Star Rating             0
# Location                0
# Nearest Landmark        0
# Distance to Landmark    0
# Price                   0
# Tax                     0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74 entries, 0 to 73
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Hotel Name            74 non-null     object
#  1   Rating                74 non-null     float64
#  2   Rating Description    74 non-null     object
#  3   Reviews               74 non-null     int64
#  4   Star Rating           74 non-null     float64
#  5   Location              74 non-null     object
#  6   Nearest Landmark      74 non-null     object
#  7   Distance to Landmark  74 non-null     float64
#  8   Price                 74 non-null     float64
#  9   Tax                   74 non-null     float64
# dtypes: float64(5), int64(1), object(4)
# memory usage: 5.9+ KB

# %%
df['Price']=df['Price'].apply(lambda x:str(x))
df['Price']=df['Price'].apply(lambda x: x.replace(',',''))
df['Price']=df['Price'].astype('float64')

# %%
def inkm(x):
  if x.split()[1]=='km':
    return float(x.split()[0])
  elif x.split()[1]=='m':
    return float(x.split()[0])/1000

df['Distance to Landmark']=df['Distance to Landmark'].apply(inkm)

# %%
df['Distance to Landmark']
# Out:
# 0     10.20
# 1     19.20
# 2      0.95
# 3      4.80
# 4      1.90
#       ...
# 69    13.20
# 70    20.60
# 71     5.80
# 72     6.60
# 73     1.30
# Name: Distance to Landmark, Length: 74, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74 entries, 0 to 73
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Hotel Name            74 non-null     object
#  1   Rating                74 non-null     float64
#  2   Rating Description    74 non-null     object
#  3   Reviews               74 non-null     int64
#  4   Star Rating           74 non-null     float64
#  5   Location              74 non-null     object
#  6   Nearest Landmark      74 non-null     object
#  7   Distance to Landmark  74 non-null     float64
#  8   Price                 74 non-null     float64
#  9   Tax                   74 non-null     float64
# dtypes: float64(5), int64(1), object(4)
# memory usage: 5.9+ KB

# %%
df.describe()  # Includes mean, std, min, max, percentiles, etc.
# Out:
#           Rating      Reviews  Star Rating  Distance to Landmark  \
# count  74.000000    74.000000    74.000000             74.000000
# mean    4.068919   375.810811     3.912281             10.521892
# std     0.401001   383.407208     0.707701              7.006742
# min     2.800000     6.000000     2.000000              0.440000
# 25%     3.900000   112.250000     3.228070              3.550000
# 50%     4.100000   240.500000     4.000000             10.800000
# 75%     4.300000   437.000000     4.000000             14.175000
# max     4.800000  1934.000000     5.000000             23.800000
#
#               Price          Tax
# count     74.000000    74.000000
# mean    3982.243243   954.180556
# std     2684.481898   786.250985
# min      930.000000   156.000000
# 25%     2282.250000   509.250000
# 50%     3037.500000   688.500000
# 75%     4994.000000   965.295139
# max    11974.000000  4617.000000

# %% [markdown]
# For categorical columns,

# %%
df.describe(include=['object'])
# Out:
#           Hotel Name Rating Description         Location Nearest Landmark
# count             74                 74               74               74
# unique            74                  4               22                2
# top     Gokulam Park          Very Good  Central Munnar       city centre
# freq               1                 43               11               56

# %%
df.select_dtypes(include='O')
# Out:
#                                            Hotel Name Rating Description  \
# 0                                        Gokulam Park          Very Good
# 1                                     Sterling Munnar          Very Good
# 2                                    Issacs Residency          Very Good
# 3                                   Tea Valley Resort          Excellent
# 4                                         Grand Plaza          Excellent
# ..                                                ...                ...
# 69                      The Fog Munnar (Resort & Spa)          Excellent
# 70               Skylark Holidays | Rooms & Caretaker          Very Good
# 71  Deshadan Mountain Resort- The highest resort i...          Excellent
# 72                          Nature Zone Jungle Resort          Very Good
# 73    Lumino Highrange Homestay | Room & Guided Treks               Good
#
#            Location    Nearest Landmark
# 0    Chithirapuram          city centre
# ...

# %%
df.describe(include='number')
# Out:
#           Rating      Reviews  Star Rating  Distance to Landmark  \
# count  74.000000    74.000000    74.000000             74.000000
# mean    4.068919   375.810811     3.912281             10.521892
# std     0.401001   383.407208     0.707701              7.006742
# min     2.800000     6.000000     2.000000              0.440000
# 25%     3.900000   112.250000     3.228070              3.550000
# 50%     4.100000   240.500000     4.000000             10.800000
# 75%     4.300000   437.000000     4.000000             14.175000
# max     4.800000  1934.000000     5.000000             23.800000
#
#               Price          Tax
# count     74.000000    74.000000
# mean    3982.243243   954.180556
# std     2684.481898   786.250985
# min      930.000000   156.000000
# 25%     2282.250000   509.250000
# 50%     3037.500000   688.500000
# 75%     4994.000000   965.295139
# max    11974.000000  4617.000000

# %%
df.select_dtypes(include='number')
# Out:
#     Rating  Reviews  Star Rating  Distance to Landmark   Price     Tax
# 0      4.1     1058     4.000000                 10.20  2728.0   574.0
# 1      3.8     1088     4.000000                 19.20  4451.0   969.0
# 2      4.1      322     3.000000                  0.95  2758.0   684.0
# 3      4.3     1337     4.000000                  4.80  2675.0   756.0
# 4      4.3     1058     4.000000                  1.90  3203.0   654.0
# ..     ...      ...          ...                   ...     ...     ...
# 69     4.5      292     5.000000                 13.20  8103.0  2178.0
# 70     4.1       17     3.912281                 20.60  3317.0   684.0
# 71     4.3      395     4.000000                  5.80  3953.0   808.0
# 72     4.1      187     4.000000                  6.60  6862.0  2124.0
# 73     3.2      221     3.912281                  1.30  1014.0   223.0
#
# [74 rows x 6 columns]

# %%
df['Distance to Landmark']
# Out:
# 0     10.20
# 1     19.20
# 2      0.95
# 3      4.80
# 4      1.90
#       ...
# 69    13.20
# 70    20.60
# 71     5.80
# 72     6.60
# 73     1.30
# Name: Distance to Landmark, Length: 74, dtype: float64

# %%
columns=list(df)

(df[columns[1:11]]==0).sum()
# Out:
# Rating                  0
# Rating Description      0
# Reviews                 0
# Star Rating             0
# Location                0
# Nearest Landmark        0
# Distance to Landmark    0
# Price                   0
# Tax                     0
# dtype: int64

# %% [markdown]
# Missing Data Analysis
# Check for missing values:

# %%
df.isnull().sum()  # Sum of missing values in each column
# Out:
# Hotel Name              0
# Rating                  0
# Rating Description      0
# Reviews                 0
# Star Rating             0
# Location                0
# Nearest Landmark        0
# Distance to Landmark    0
# Price                   0
# Tax                     0
# dtype: int64

# %%
import seaborn as sns
sns.heatmap(df.isnull(), cbar=False, cmap='viridis')
# Out:
# <Axes: >

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74 entries, 0 to 73
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Hotel Name            74 non-null     object
#  1   Rating                74 non-null     float64
#  2   Rating Description    74 non-null     object
#  3   Reviews               74 non-null     int64
#  4   Star Rating           74 non-null     float64
#  5   Location              74 non-null     object
#  6   Nearest Landmark      74 non-null     object
#  7   Distance to Landmark  74 non-null     float64
#  8   Price                 74 non-null     float64
#  9   Tax                   74 non-null     float64
# dtypes: float64(5), int64(1), object(4)
# memory usage: 5.9+ KB

# %%
from timeit import default_timer as t
start=t()
for i in df.columns:
  print(f'{i} n-uniques are {df[i].nunique()}')
  end=t()
print(f'time taken to execute the loop is {end-start}')
# Out:
# Hotel Name n-uniques are 74
# Rating n-uniques are 18
# Rating Description n-uniques are 4
# Reviews n-uniques are 70
# Star Rating n-uniques are 5
# Location n-uniques are 22
# Nearest Landmark n-uniques are 2
# Distance to Landmark n-uniques are 57
# Price n-uniques are 72
# Tax n-uniques are 71
# time taken to execute the loop is 0.002403006000008645

# %%
df['Star Rating']=df['Star Rating'].astype('int8')

# %%
df['Star Rating'].value_counts()
# Out:
# Star Rating
# 3    35
# 4    23
# 5    15
# 2     1
# Name: count, dtype: int64

# %%
df['Rating Description'].value_counts()
# Out:
# Rating Description
# Very Good    43
# Excellent    25
# Good          5
# Average       1
# Name: count, dtype: int64

# %%
sys.getsizeof(df)
# Out:
# 24471

# %%
df.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_abfdc" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_abfdc_level0_col0" class="col_heading level0 col0" >Hotel Name</th>
#       <th id="T_abfdc_level0_col1" class="col_heading level0 col1" >Rating</th>
#       <th id="T_abfdc_level0_col2" class="col_heading level0 col2" >Rating Description</th>
#       <th id="T_abfdc_level0_col3" class="col_heading level0 col3" >Reviews</th>
#       <th id="T_abfdc_level0_col4" class="col_heading level0 col4" >Star Rating</th>
#       <th id="T_abfdc_level0_col5" class="col_heading level0 col5" >Location</th>
#       <th id="T_abfdc_level0_col6" class="col_heading level0 col6" >Nearest Landmark</th>
#       <th id="T_abfdc_level0_col7" class="col_heading level0 col7" >Distance to Landmark</th>
#       <th id="T_abfdc_level0_col8" class="col_heading level0 col8" >Price</th>
# ...

# %%
df.style.background_gradient(cmap='viridis')
# Out:
# <style type="text/css">
# #T_5ea40_row0_col1, #T_5ea40_row2_col1, #T_5ea40_row9_col1, #T_5ea40_row37_col1, #T_5ea40_row53_col1, #T_5ea40_row55_col7, #T_5ea40_row66_col1, #T_5ea40_row69_col8, #T_5ea40_row70_col1, #T_5ea40_row72_col1 {
#   background-color: #2fb47c;
#   color: #f1f1f1;
# }
# #T_5ea40_row0_col3, #T_5ea40_row4_col3, #T_5ea40_row69_col7 {
#   background-color: #1e9b8a;
#   color: #f1f1f1;
# }
# #T_5ea40_row0_col4, #T_5ea40_row1_col4, #T_5ea40_row3_col4, #T_5ea40_row4_col4, #T_5ea40_row5_col4, #T_5ea40_row6_col4, #T_5ea40_row8_col4, #T_5ea40_row10_col4, #T_5ea40_row17_col4, #T_5ea40_row19_col4, #T_5ea40_row26_col4, #T_5ea40_row28_col4, #T_5ea40_row29_col4, #T_5ea40_row34_col4, #T_5ea40_row42_col4, #T_5ea40_row46_col4, #T_5ea40_row53_col4, #T_5ea40_row57_col4, #T_5ea40_row59_col4, #T_5ea40_row64_col4, #T_5ea40_row68_col4, #T_5ea40_row71_col4, #T_5ea40_row72_col4 {
#   background-color: #35b779;
#   color: #f1f1f1;
# }
# #T_5ea40_row0_col7, #T_5ea40_row68_col7 {
# ...

# %%
df.style.background_gradient(cmap='viridis')

df.style.highlight_max(color='red').highlight_min(color='yellow')
# Out:
# <style type="text/css">
# ...

# %%
df.style.bar()
# Out:
# <style type="text/css">
# #T_3e57b_row0_col1, #T_3e57b_row2_col1, #T_3e57b_row9_col1, #T_3e57b_row37_col1, #T_3e57b_row53_col1, #T_3e57b_row66_col1, #T_3e57b_row70_col1, #T_3e57b_row72_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 85.4%, transparent 85.4%);
# }
# #T_3e57b_row0_col3, #T_3e57b_row4_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 54.7%, transparent 54.7%);
# }
# #T_3e57b_row0_col4, #T_3e57b_row1_col4, #T_3e57b_row3_col4, #T_3e57b_row4_col4, #T_3e57b_row5_col4, #T_3e57b_row6_col4, #T_3e57b_row8_col4, #T_3e57b_row10_col4, #T_3e57b_row17_col4, #T_3e57b_row19_col4, #T_3e57b_row26_col4, #T_3e57b_row28_col4, #T_3e57b_row29_col4, #T_3e57b_row34_col4, #T_3e57b_row42_col4, #T_3e57b_row46_col4, #T_3e57b_row53_col4, #T_3e57b_row57_col4, #T_3e57b_row59_col4, #T_3e57b_row64_col4, #T_3e57b_row68_col4, #T_3e57b_row71_col4, #T_3e57b_row72_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 80.0%, transparent 80.0%);
# ...

# %%
df[['Hotel Name','Rating','Rating Description','Price']].style.bar(color=['green','blue'])
# Out:
# <style type="text/css">
# #T_3a73b_row0_col1, #T_3a73b_row2_col1, #T_3a73b_row9_col1, #T_3a73b_row37_col1, #T_3a73b_row53_col1, #T_3a73b_row66_col1, #T_3a73b_row70_col1, #T_3a73b_row72_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, blue 85.4%, transparent 85.4%);
# }
# #T_3a73b_row0_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, blue 22.8%, transparent 22.8%);
# }
# #T_3a73b_row1_col1, #T_3a73b_row20_col1, #T_3a73b_row25_col1, #T_3a73b_row39_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, blue 79.2%, transparent 79.2%);
# }
# #T_3a73b_row1_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, blue 37.2%, transparent 37.2%);
# }
# #T_3a73b_row2_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, blue 23.0%, transparent 23.0%);
# }
# #T_3a73b_row3_col1, #T_3a73b_row4_col1, #T_3a73b_row11_col1, #T_3a73b_row41_col1, #T_3a73b_row45_col1, #T_3a73b_row60_col1, #T_3a73b_row61_col1, #T_3a73b_row71_col1 {
#   width: 10em;
# ...

# %%
df[['Rating','Rating Description','Price']].style.bar(subset=['Rating'],color='orange').bar(subset=['Price'],color='red').set_table_styles([{'selector':'th ,td:nth-child(2)','props':[('color','pink')]}])
# Out:
# <style type="text/css">
# #T_aab79 th  {
#   color: pink;
# }
# #T_aab79 td:nth-child(2) {
#   color: pink;
# }
# #T_aab79_row0_col0, #T_aab79_row2_col0, #T_aab79_row9_col0, #T_aab79_row37_col0, #T_aab79_row53_col0, #T_aab79_row66_col0, #T_aab79_row70_col0, #T_aab79_row72_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, orange 85.4%, transparent 85.4%);
# }
# #T_aab79_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, red 22.8%, transparent 22.8%);
# }
# #T_aab79_row1_col0, #T_aab79_row20_col0, #T_aab79_row25_col0, #T_aab79_row39_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, orange 79.2%, transparent 79.2%);
# }
# #T_aab79_row1_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, red 37.2%, transparent 37.2%);
# }
# #T_aab79_row2_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, red 23.0%, transparent 23.0%);
# }
# ...

# %%
for i,j in enumerate(df.columns):
  print(i,j)
# Out:
# 0 Hotel Name
# 1 Rating
# 2 Rating Description
# 3 Reviews
# 4 Star Rating
# 5 Location
# 6 Nearest Landmark
# 7 Distance to Landmark
# 8 Price
# 9 Tax

# %%
import matplotlib.pyplot as plt
import seaborn as sns
for i,j in enumerate(df.columns):
  if df[j].dtype == 'float':
    plt.figure(i)
    sns.distplot(df[j],kde=False)
# Out:
# <ipython-input-73-f7b8db1e01c0>:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[j],kde=False)

# %%
sns.boxplot(df['Price'],orient='h')
# Out:
# <Axes: xlabel='Price'>

# %%
sns.distplot(df['Price'],kde=True)
# Out:
# <ipython-input-77-40b1373bcc37>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Price'],kde=True)
# <Axes: xlabel='Price', ylabel='Density'>

# %%
df['Rating']=df['Rating'].groupby(df['Rating Description']).transform('mean')
df['Rating']
df.groupby('Rating')['Rating'].value_counts().index
# Out:
# Index([2.8, 3.2399999999999998, 3.967441860465116, 4.46], dtype='float64', name='Rating')

# %%
df.groupby('Rating')['Rating'].value_counts().values
# Out:
# array([ 1,  5, 43, 25])

# %%
x=df.groupby('Rating')['Rating'].count().index
y=df.groupby('Rating')['Rating'].value_counts().values
plt.figure(figsize=(10,5))
sns.barplot(x=x,y=y,hue=x)
# Out:
# <Axes: xlabel='Rating'>

# %%
x=df.groupby('Rating Description')['Rating Description'].count().index
y=df.groupby('Rating Description')['Rating Description'].value_counts().values
sns.barplot(x=x,y=y,hue=y,color='red')
# Out:
# <ipython-input-101-8946672ce199>:3: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:red'` for the same effect.
#
#   sns.barplot(x=x,y=y,hue=y,color='red')
# <Axes: xlabel='Rating Description'>

# %%
df['rating_desc']=df['Rating Description'].map({'Very Good':5,'Excellent':4,'Good':3,'Average':2,'Poor':1})
df['rating_desc']
df.groupby('rating_desc')['rating_desc'].value_counts()
# Out:
# rating_desc
# 2     1
# 3     5
# 4    25
# 5    43
# Name: count, dtype: int64

# %%
x=df.groupby('rating_desc')['rating_desc'].count().index
y=df.groupby('rating_desc')['rating_desc'].value_counts().values
sns.barplot(x=x,y=y,hue=y,color='yellow')
# Out:
# <ipython-input-112-5a9354895a45>:3: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:yellow'` for the same effect.
#
#   sns.barplot(x=x,y=y,hue=y,color='yellow')
# <Axes: xlabel='rating_desc'>

# %%
sns.jointplot(x=df['Rating'],y=df['Price'],kind='reg')

# %%
sns.jointplot(x=df['Reviews'],y=df['Price'],kind='reg',color='green')

# %%
sns.relplot(x=df['Reviews'],y=df['Price'],hue=df['Rating'],col=df['Rating Description'],kind='scatter')

# %%
sns.violinplot(x=df['Rating'],y=df['Price'],hue=df['Nearest Landmark'])
# Out:
# <Axes: xlabel='Rating', ylabel='Price'>

# %%
sns.violinplot(x=df['Price'],y=df['Rating Description'],hue=df['Nearest Landmark'],split=True)
# Out:
# <Axes: xlabel='Price', ylabel='Rating Description'>

# %%
x=df.groupby('Rating Description')['Rating Description'].value_counts()
x
# Out:
# Rating Description
# Average       1
# Excellent    25
# Good          5
# Very Good    43
# Name: count, dtype: int64

# %%
plt.pie(x,labels=x.index,autopct='%.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7daf0bb89e90>,
# ...
#  [Text(1.0990088627746966, 0.04668532470346795, 'Average'),
#   Text(0.453091347554786, 1.002351350959826, 'Excellent'),
#   Text(-0.8257395074476738, 0.7267422279185882, 'Good'),
#   Text(-0.2771761710484151, -1.0645061625950973, 'Very Good')],
#  [Text(0.599459379695289, 0.02546472256552797, '1.35%'),
#   Text(0.24714073502988324, 0.5467371005235414, '33.78%'),
#   Text(-0.45040336769873107, 0.39640485159195715, '6.76%'),
#   Text(-0.15118700239004457, -0.5806397250518712, '58.11%')])

# %%
plt.pie(x,labels=x.values,autopct='%1.0f%%',explode=[0.1,0.1,0.1,1])
# Out:
# ([<matplotlib.patches.Wedge at 0x7daf0be47b90>,
# ...
#  [Text(1.1989187593905781, 0.05092944513105595, '1'),
#   Text(0.4942814700597665, 1.093474201047083, '25'),
#   Text(-0.9008067353974623, 0.7928097031839144, '5'),
#   Text(-0.5291545083651561, -2.0322390376815496, '43')],
#  [Text(0.6993692763111705, 0.029708842993115967, '1%'),
#   Text(0.28833085753486376, 0.6378599506107983, '34%'),
#   Text(-0.5254705956485196, 0.46247232685728334, '7%'),
#   Text(-0.40316533970678553, -1.5483726001383233, '58%')])

# %%
plt.pie(x.values,labels=x.index,autopct='%1.4f%%',explode=[0.1,0.1,0.1,0.1],shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x7daf0be0ac90>,
# ...
#  [Text(1.1989187593905781, 0.05092944513105595, 'Average'),
#   Text(0.4942814700597665, 1.093474201047083, 'Excellent'),
#   Text(-0.9008067353974623, 0.7928097031839144, 'Good'),
#   Text(-0.3023740047800892, -1.1612794501037427, 'Very Good')],
#  [Text(0.6993692763111705, 0.029708842993115967, '1.3514%'),
#   Text(0.28833085753486376, 0.6378599506107983, '33.7838%'),
#   Text(-0.5254705956485196, 0.46247232685728334, '6.7568%'),
#   Text(-0.17638483612171868, -0.6774130125605164, '58.1081%')])

# %%
plt.pie(x,labels=x.index,autopct='%0.2f%%',radius=3,explode=[0.1,0.1,0.1,0.1],shadow=True,colors=['red','green','blue','yellow'])
# Out:
# ([<matplotlib.patches.Wedge at 0x7daf0ba5b690>,
# ...
#  [Text(3.396936484939971, 0.14430009453799184, 'Average'),
#   Text(1.4004641651693384, 3.0981769029667348, 'Excellent'),
#   Text(-2.55228575029281, 2.2462941590210908, 'Good'),
#   Text(-0.8567263468769193, -3.2902917752939373, 'Very Good')],
#  [Text(1.8982880357017484, 0.08063828812417191, '1.35%'),
#   Text(0.7826123275946303, 1.731334151657881, '33.78%'),
#   Text(-1.4262773310459818, 1.2552820300411973, '6.76%'),
#   Text(-0.4787588409018078, -1.838692462664259, '58.11%')])

# %%
sns.barplot(x=df['Rating Description'],y=df['Price'],hue=df['Nearest Landmark'])
# Out:
# <Axes: xlabel='Rating Description', ylabel='Price'>

# %%
sns.scatterplot(x=df['Rating'],y=df['Price'],hue=df['Nearest Landmark'])
# Out:
# <Axes: xlabel='Rating', ylabel='Price'>

# %%
df.describe()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74 entries, 0 to 73
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Hotel Name            74 non-null     object
#  1   Rating                74 non-null     float64
#  2   Rating Description    74 non-null     object
#  3   Reviews               74 non-null     int64
#  4   Star Rating           74 non-null     int8
#  5   Location              74 non-null     object
#  6   Nearest Landmark      74 non-null     object
#  7   Distance to Landmark  74 non-null     float64
#  8   Price                 74 non-null     float64
#  9   Tax                   74 non-null     float64
#  10  rating_desc           74 non-null     int64
# dtypes: float64(4), int64(2), int8(1), object(4)
# memory usage: 6.0+ KB

# %%
# Lets answer few questions- Business standpoint.
# Lets say you are a Business analyst / data analyst. A hotel xyz comes to you and says.
# I am not getting customers. How should I set the price for my property? Say hotel- Nature Zone Jungle Resort
# There can be multiple questions that can be answered / is required to be answered to solve a Business problem which
# will require drilling down to data level analysis

# %%
sns.barplot(x=df['Nearest Landmark'],y=df['Price'],hue=df['Distance to Landmark'])
# Out:
# <Axes: xlabel='Nearest Landmark', ylabel='Price'>

# %%
df[df['Hotel Name']=='Nature Zone Jungle Resort']
# Out:
#                    Hotel Name    Rating Rating Description  Reviews  \
# 72  Nature Zone Jungle Resort  3.967442          Very Good      187
#
#     Star Rating     Location Nearest Landmark  Distance to Landmark   Price  \
# 72            4  Pallivasal       city centre                   6.6  6862.0
#
#        Tax  rating_desc
# 72  2124.0            5

# %%
def dis_check(x):
  if x<=6:
    return 'Very Near (0 Km - 6 Km]'
  elif x<=12:
    return "Near (6 Km - 12 Km]"
  elif x<=20:
    return "Moderate (12 Km - 20 Km]"
  else:
    return "Far (> 20 Km]"
def rate(x):
  if x>=4:
    return "Better Ratings"
  else:
    return 'worse rating'

# %%
df[['Hotel Name','Distance to Landmark','Price']].sort_values(by='Distance to Landmark',ascending=False).tail(10)
# Out:
#                                          Hotel Name  Distance to Landmark  \
# 10                                  KTDC Tea County                  1.70
# 32                                     Le Celestium                  1.70
# 39                                    Munnar Castle                  1.70
# 58                             Tea Garden Riverside                  1.30
# 73  Lumino Highrange Homestay | Room & Guided Treks                  1.30
# 16         Landy Queen Homestay | Rooms & Caretaker                  1.10
# 2                                  Issacs Residency                  0.95
# 23                                Bellmount Resorts                  0.86
# 6                                    Eastend Munnar                  0.77
# 63                                       Munnar Inn                  0.44
#
#      Price
# 10  5022.0
# 32  1674.0
# 39  2365.0
# 58  2177.0
# 73  1014.0
# 16  1279.0
# 2   2758.0
# 23  2364.0
# 6   3493.0
# 63  2046.0

# %%
df['nearness 2 landmark']=df['Distance to Landmark'].apply(lambda x: dis_check(x))
df['nearness 2 landmark']
# Out:
# 0          Near (6 Km - 12 Km]
# 1     Moderate (12 Km - 20 Km]
# 2      Very Near (0 Km - 6 Km]
# 3      Very Near (0 Km - 6 Km]
# 4      Very Near (0 Km - 6 Km]
#                 ...
# 69    Moderate (12 Km - 20 Km]
# 70               Far (> 20 Km]
# 71     Very Near (0 Km - 6 Km]
# 72         Near (6 Km - 12 Km]
# 73     Very Near (0 Km - 6 Km]
# Name: nearness 2 landmark, Length: 74, dtype: object

# %%
df[df['Nearest Landmark']== "city centre"]
# Out:
#                                            Hotel Name    Rating  \
# 0                                        Gokulam Park  3.967442
# 1                                     Sterling Munnar  3.967442
# 3                                   Tea Valley Resort  4.460000
# 5                               Misty Mountain Resort  3.967442
# 7                     Seven Springs Plantation Resort  3.967442
# 9                             Broad Bean Resort & Spa  3.967442
# 11                            Parakkat Nature Resorts  4.460000
# 12  Chithirapuram Palace | Rooms & Restaurant\nLik...  4.460000
# 13        Devonshire Greens - The Leisure Hotel & Spa  3.967442
# 14                                    Sn Holiday Home  3.967442
# 15                                        Vibe Munnar  4.460000
# 17                               juSTa Rangers Munnar  3.967442
# 18                              The Panoramic Getaway  4.460000
# 20                                         Tea Castle  3.967442
# ...

# %%
sns.boxplot(x='Price',y='nearness 2 landmark', data=df[df['Nearest Landmark']== "city centre"])
# Out:
# <Axes: xlabel='Price', ylabel='nearness 2 landmark'>

# %%
def dis_check(x):
  if x<=6:
    return 'Very Near (0 Km - 6 Km]'
  elif x<=12:
    return "Near (6 Km - 12 Km]"
  elif x<=20:
    return "Moderate (12 Km - 20 Km]"
  else:
    return "Far (> 20 Km]"
def rate(x):
  if x>=4:
    return "Better Ratings"
  else:
    return 'worse rating'

# %%
df['rating of other resort compared to jungle resort']=df['Rating'].apply(lambda x: rate(x))
df['rating of other resort compared to jungle resort']
# Out:
# 0       worse rating
# 1       worse rating
# 2       worse rating
# 3     Better Ratings
# 4     Better Ratings
#            ...
# 69    Better Ratings
# 70      worse rating
# 71    Better Ratings
# 72      worse rating
# 73      worse rating
# Name: rating of other resort compared to jungle resort, Length: 74, dtype: object

# %%
sns.boxplot(x='Price',y='rating of other resort compared to jungle resort', data=df[df['Nearest Landmark']== "city centre"],hue='nearness 2 landmark')
# Out:
# <Axes: xlabel='Price', ylabel='rating of other resort compared to jungle resort'>

# %%
plt.figure(figsize=(20,5))
sns.boxplot(x='Price',y='nearness 2 landmark', data=df[df['Nearest Landmark']== "city centre"],hue='rating of other resort compared to jungle resort')
# Out:
# <Axes: xlabel='Price', ylabel='nearness 2 landmark'>
